# %%
# %load_ext lab_black

# %%
import pandas as pd

# %%
def structurize(set_: set) -> pd.DataFrame:
    return pd.DataFrame(list(set_), columns=["CpG"]).set_index("CpG")


def extract(df, threshold=0.1, alpha=0.05):
    """Function to extract CpGs from report"""
    df = df[(df["Delta mean"].abs() > threshold) & (df["q-value"] <= alpha)]
    return set(df.index)

# %%
epic = pd.read_csv("../data/Additional/EPIC/MethylationEPIC_v-1-0_B4.csv", index_col=0, low_memory=False)
epic = epic[["UCSC_RefGene_Name", "UCSC_RefGene_Group", "Relation_to_UCSC_CpG_Island"]]

# %%
epic
# Out:
#                   UCSC_RefGene_Name   UCSC_RefGene_Group  \
# IlmnID
# cg07881041  PTPRS;PTPRS;PTPRS;PTPRS  Body;Body;Body;Body
# cg18478105                   YTHDF1               TSS200
# cg23229610                      NaN                  NaN
# cg03513874                      NaN                  NaN
# cg09835024                   EIF2S3              TSS1500
# ...                             ...                  ...
# 71678368                        NaN                  NaN
# 72748406                        NaN                  NaN
# 73635489                        NaN                  NaN
# 73784382                        NaN                  NaN
# 73794434                        NaN                  NaN
#
#            Relation_to_UCSC_CpG_Island
# IlmnID
# cg07881041                     N_Shore
# cg18478105                      Island
# cg23229610                     N_Shelf
# cg03513874                     S_Shelf
# cg09835024                      Island
# ...                                ...
# 71678368                           NaN
# 72748406                           NaN
# 73635489                           NaN
# 73784382                           NaN
# 73794434                           NaN
#
# [866554 rows x 3 columns]

# %%
# All DMPs in ALL cov groups vs HB

# %%
report = pd.read_csv("../DMPsInAllCoVGroups.csv", index_col=0).set_index("CpG")
report = pd.concat((report, epic.loc[report.index]), axis=1)
report.to_csv("../Annots/DMPsInAllStudiesAnnots.csv")
report
# Out:
#                UCSC_RefGene_Name  UCSC_RefGene_Group  \
# CpG
# cg10182306  CLCNKA;CLCNKA;CLCNKA      Body;Body;Body
# cg09622330  GRIN2A;GRIN2A;GRIN2A      Body;Body;Body
# cg08585897     KARS;TERF2IP;KARS  5'UTR;TSS1500;Body
# cg15004555                  AIM2                Body
# cg02187666                   NaN                 NaN
# ...                          ...                 ...
# cg10299917                 LRP5L               5'UTR
# cg07222421                MSTO2P                Body
# cg10690677           CLCA4;CLCA4           Body;Body
# cg18507060             OAS3;OAS3        ExonBnd;Body
# cg12981595              KRTAP4-8              TSS200
#
#            Relation_to_UCSC_CpG_Island
# CpG
# cg10182306                         NaN
# cg09622330                         NaN
# cg08585897                     N_Shore
# cg15004555                         NaN
# cg02187666                         NaN
# ...                                ...
# cg10299917                         NaN
# cg07222421                     S_Shelf
# cg10690677                      Island
# cg18507060                         NaN
# cg12981595                         NaN
#
# [104 rows x 3 columns]

# %%
# non-Cov vs HB

# %%
report = structurize(extract(pd.read_csv("output/USANoNCoV_vs_HB_ALLProbes.csv", index_col=0)))
report = pd.concat((report, epic.loc[report.index]), axis=1)
report.to_csv("../Annots/DMPsNonCovVsHBAnnots.csv")
report
# Out:
#                                             UCSC_RefGene_Name  \
# CpG
# cg12981595                                           KRTAP4-8
# cg11325989                                              KRT6A
# cg25060243  UGT1A10;UGT1A6;UGT1A8;UGT1A6;UGT1A9;UGT1A4;UGT...
# cg10685380                                              IL12B
# cg15882280                                                NaN
# ...                                                       ...
# cg02568557                                              BARX2
# cg19963700                                          ROR1;ROR1
# cg19048658                                                NaN
# cg10162971                                              GRHL1
# cg09232520                                  TRPS1;TRPS1;TRPS1
#
#                                     UCSC_RefGene_Group  \
# CpG
# cg12981595                                      TSS200
# cg11325989                                        Body
# cg25060243  Body;Body;Body;Body;Body;TSS1500;Body;Body
# cg10685380                                        Body
# cg15882280                                         NaN
# ...                                                ...
# cg02568557                                        Body
# cg19963700                                   Body;Body
# cg19048658                                         NaN
# cg10162971                                        Body
# cg09232520                              Body;Body;Body
#
#            Relation_to_UCSC_CpG_Island
# CpG
# cg12981595                         NaN
# cg11325989                         NaN
# cg25060243                         NaN
# cg10685380                         NaN
# cg15882280                         NaN
# ...                                ...
# cg02568557                         NaN
# cg19963700                         NaN
# cg19048658                         NaN
# cg10162971                     S_Shore
# cg09232520                         NaN
#
# [144 rows x 3 columns]

# %%
# non Cov vs CoV

# %%
report = structurize(extract(pd.read_csv("output/USANoNCoV_vs_CoV_ALLProbes.csv", index_col=0)))
report = pd.concat((report, epic.loc[report.index]), axis=1)
report.to_csv("../Annots/DMPsNonCovVsCoVAnnots.csv")
report
# Out:
#            UCSC_RefGene_Name UCSC_RefGene_Group Relation_to_UCSC_CpG_Island
# CpG
# cg10123669             STK39               Body                         NaN
# cg11015557              POLE               Body                         NaN
# cg02770216       AKAP9;AKAP9          Body;Body                         NaN
# cg15215519               NaN                NaN                         NaN
# cg14366738            IGFBP5               Body                         NaN
# ...                      ...                ...                         ...
# cg17114584    IRF7;IRF7;IRF7     Body;Body;Body                     N_Shore
# cg03607951            IFI44L            TSS1500                         NaN
# cg17354858               NaN                NaN                         NaN
# cg24388175    PCCA;PCCA;PCCA     Body;Body;Body                         NaN
# cg13982456               NaN                NaN                     S_Shelf
#
# [168 rows x 3 columns]
