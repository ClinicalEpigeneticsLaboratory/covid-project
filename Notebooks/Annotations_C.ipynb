# %%
# Notebook: Notebook to annotate CpGs
# Description:  ...

# %%
# %load_ext lab_black

# %%
import pandas as pd

# %%
def structurize(set_: set) -> pd.DataFrame:
    """
    Convert set to DataFrame.
    """
    return pd.DataFrame(list(set_), columns=["CpG"]).set_index("CpG")


def extract(df, threshold=0.1, alpha=0.05):
    """Function to extract CpGs from report"""
    df = df[(df["Delta mean"].abs() > threshold) & (df["q-value"] <= alpha)]
    return set(df.index)

# %%
# Load EPIC

# %%
epic = pd.read_csv(
    "../data/Additional/EPIC/MethylationEPIC_v-1-0_B4.csv",
    index_col=0,
    low_memory=False,
)
epic = epic[["UCSC_RefGene_Name", "UCSC_RefGene_Group", "Relation_to_UCSC_CpG_Island"]]

# %%
epic
# Out:
#                   UCSC_RefGene_Name   UCSC_RefGene_Group  \
# IlmnID
# cg07881041  PTPRS;PTPRS;PTPRS;PTPRS  Body;Body;Body;Body
# cg18478105                   YTHDF1               TSS200
# cg23229610                      NaN                  NaN
# cg03513874                      NaN                  NaN
# cg09835024                   EIF2S3              TSS1500
# ...                             ...                  ...
# 71678368                        NaN                  NaN
# 72748406                        NaN                  NaN
# 73635489                        NaN                  NaN
# 73784382                        NaN                  NaN
# 73794434                        NaN                  NaN
#
#            Relation_to_UCSC_CpG_Island
# IlmnID
# cg07881041                     N_Shore
# cg18478105                      Island
# cg23229610                     N_Shelf
# cg03513874                     S_Shelf
# cg09835024                      Island
# ...                                ...
# 71678368                           NaN
# 72748406                           NaN
# 73635489                           NaN
# 73784382                           NaN
# 73794434                           NaN
#
# [866554 rows x 3 columns]

# %%
# DMPs in ALL covid groups vs HB

# %%
report = pd.read_csv("../Files/DMPsInAllCoVGroup", index_col=0).set_index("CpG")
report = pd.concat((report, epic.loc[report.index]), axis=1)
report.to_csv("../Annots/DMPsInAllStudiesAnnots.csv")
report
# Out:
#               UCSC_RefGene_Name  UCSC_RefGene_Group  \
# CpG
# cg20232119               HSPA1L                Body
# cg10827434                 RPF1             1stExon
# cg14094333   KLF3;KLF3;FLJ13197  1stExon;5'UTR;Body
# cg13407664                 HTN1             TSS1500
# cg08609238                  NaN                 NaN
# ...                         ...                 ...
# cg11962649                HSPA5                Body
# cg08323960                  NaN                 NaN
# cg27323430    FLJ44606;FLJ44606           Body;Body
# cg00574307              DCT;DCT           Body;Body
# cg15272186  LOC285830;LOC285830           Body;Body
#
#            Relation_to_UCSC_CpG_Island
# CpG
# cg20232119                     S_Shelf
# cg10827434                      Island
# cg14094333                      Island
# cg13407664                         NaN
# cg08609238                      Island
# ...                                ...
# cg11962649                     N_Shore
# cg08323960                         NaN
# cg27323430                         NaN
# cg00574307                         NaN
# cg15272186                         NaN
#
# [104 rows x 3 columns]

# %%
# DMPs non-Covid vs HB

# %%
report = structurize(
    extract(pd.read_csv("output/USANoNCoV_vs_HB_ALLProbes.csv", index_col=0))
)
report = pd.concat((report, epic.loc[report.index]), axis=1)
report.to_csv("../Annots/DMPsNonCovVsHBAnnots.csv")
report
# Out:
#            UCSC_RefGene_Name UCSC_RefGene_Group Relation_to_UCSC_CpG_Island
# CpG
# cg22726533     YAE1D1;YAE1D1          Body;Body                     S_Shelf
# cg10211530            TNRC18               Body                     N_Shore
# cg20232119            HSPA1L               Body                     S_Shelf
# cg05521474               NaN                NaN                         NaN
# cg08609238               NaN                NaN                      Island
# ...                      ...                ...                         ...
# cg04783624            RANBP9               Body                         NaN
# cg10685380             IL12B               Body                         NaN
# cg25940202               NaN                NaN                         NaN
# cg08022717           CYP27C1               Body                         NaN
# cg19963700         ROR1;ROR1          Body;Body                         NaN
#
# [144 rows x 3 columns]

# %%
# DMPs non-Cov vs CoV [USA]

# %%
report = structurize(
    extract(pd.read_csv("output/USANoNCoV_vs_CoV_ALLProbes.csv", index_col=0))
)
report = pd.concat((report, epic.loc[report.index]), axis=1)
report.to_csv("../Annots/DMPsNonCovVsCoVAnnots.csv")
report
# Out:
#                      UCSC_RefGene_Name  UCSC_RefGene_Group  \
# CpG
# cg14541119   LOC100507477;LOC100507477           Body;Body
# cg06712932               PLXNC1;PLXNC1           Body;Body
# cg01176329        GABBR1;GABBR1;GABBR1      Body;Body;Body
# cg24103563  TRIM34;TRIM34;TRIM6-TRIM34  TSS1500;5'UTR;Body
# cg20426042                        PGCP               5'UTR
# ...                                ...                 ...
# cg16168081                         NaN                 NaN
# cg03037271                         NaN                 NaN
# cg18557047          TET2;TET2;TET2-AS1    5'UTR;5'UTR;Body
# cg17114584              IRF7;IRF7;IRF7      Body;Body;Body
# cg26314172                         TOX                Body
#
#            Relation_to_UCSC_CpG_Island
# CpG
# cg14541119                         NaN
# cg06712932                         NaN
# cg01176329                     N_Shelf
# cg24103563                         NaN
# cg20426042                         NaN
# ...                                ...
# cg16168081                     N_Shore
# cg03037271                         NaN
# cg18557047                         NaN
# cg17114584                     N_Shore
# cg26314172                         NaN
#
# [168 rows x 3 columns]
