# %%
# Notebook: Cell fraction correction
# Description:  Notebook with analysis of cell fraction correction

# %%
# %load_ext lab_black
# Out:
# The lab_black extension is already loaded. To reload it, use:
#   %reload_ext lab_black

# %%
import os

import numpy as np
import pandas as pd
import seaborn as sns
from tqdm import tqdm
import scipy.stats as sts

import plotly.express as px
import matplotlib.pyplot as plt

from sklearn.metrics import r2_score
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression

# %%
# Load data

# %%
spain_labels = pd.read_csv(
    "../data/raw/CONCATED_Spain_HB/SampleSheetSpain.csv", index_col=0
)["Sample_Group"]
spain_labels = spain_labels.map(
    lambda x: "Helathy Blood" if not "Spain" in x else "Covid-19"
)
spain_labels
# Out:
# Sample_Name
# GSM5163386            Covid-19
# GSM5163387            Covid-19
# GSM5163388            Covid-19
# GSM5163389            Covid-19
# GSM5163390            Covid-19
#                      ...
# HB_Control_78    Helathy Blood
# HB_Control_79    Helathy Blood
# HB_Control_80    Helathy Blood
# HB_Control_81    Helathy Blood
# HB_Control_82    Helathy Blood
# Name: Sample_Group, Length: 490, dtype: object

# %%
# raw WBC fractions - before correction

# %%
spain_cf = pd.read_csv("../data/processed/CF/Spain_before_CFC.csv", index_col=0)
spain_cf = pd.concat((spain_cf, spain_labels), axis=1)
spain_cf
# Out:
#                       B        NK      CD4T      CD8T      Mono    Neutro  \
# GSM5163593     0.002257  0.023829  0.195079  0.049923  0.065042  0.663872
# GSM5163624     0.000000  0.141800  0.125534  0.022799  0.052468  0.657399
# HB_Control_26  0.000000  0.152049  0.158047  0.002009  0.096114  0.591781
# GSM5163732     0.025770  0.091979  0.228205  0.044410  0.106320  0.503316
# HB_Control_49  0.009619  0.068933  0.074765  0.000000  0.092905  0.753778
# ...                 ...       ...       ...       ...       ...       ...
# GSM5163596     0.019290  0.000000  0.200085  0.000000  0.083151  0.697474
# GSM5163503     0.000000  0.000000  0.234437  0.006541  0.100711  0.658311
# GSM5163456     0.000000  0.171187  0.000000  0.129440  0.083872  0.615501
# GSM5163709     0.009710  0.025270  0.107237  0.057689  0.046407  0.753687
# GSM5163522     0.014003  0.000000  0.154039  0.063478  0.057297  0.711183
#
#                Eosino   Sample_Group
# GSM5163593        0.0       Covid-19
# GSM5163624        0.0       Covid-19
# HB_Control_26     0.0  Helathy Blood
# GSM5163732        0.0       Covid-19
# HB_Control_49     0.0  Helathy Blood
# ...               ...            ...
# GSM5163596        0.0       Covid-19
# GSM5163503        0.0       Covid-19
# GSM5163456        0.0       Covid-19
# GSM5163709        0.0       Covid-19
# GSM5163522        0.0       Covid-19
#
# [490 rows x 8 columns]

# %%
# WBC - no correction

# %%
spain_cf.Sample_Group = spain_cf.Sample_Group.map(
    {"Covid-19": "COVID-19 SPAIN", "Helathy Blood": "Healthy"}
)
fig = px.box(
    spain_cf,
    color="Sample_Group",
    labels={"variable": "", "value": "Frequency [%]"},
)

fig.update_layout(legend=dict(font=dict(size=24), title=""), font=dict(size=22))
fig.update_traces(marker=dict(size=10))
fig.update_yaxes(range=[0, 1])

fig.write_image("../Plots/CF_before_CFC.jpg")
fig.show()

# %%
# WBC fractions - after correction

# %%
spain_cfc = pd.read_csv("../data/processed/CF/Spain_after_CFC.csv", index_col=0)
spain_cfc = pd.concat((spain_cfc, spain_labels), axis=1)
spain_cfc
# Out:
#                       B        NK      CD4T      CD8T      Mono    Neutro  \
# GSM5163593     0.012376  0.052503  0.104355  0.067339  0.084163  0.679264
# GSM5163624     0.002045  0.055807  0.109174  0.066488  0.082781  0.683704
# HB_Control_26  0.014302  0.033594  0.099995  0.078422  0.082577  0.691111
# GSM5163732     0.009225  0.048635  0.097126  0.066814  0.085211  0.692989
# HB_Control_49  0.015740  0.054853  0.110372  0.068427  0.082830  0.667778
# ...                 ...       ...       ...       ...       ...       ...
# GSM5163596     0.010120  0.043428  0.110472  0.050021  0.087111  0.698849
# GSM5163503     0.000000  0.031075  0.108463  0.070483  0.087605  0.702374
# GSM5163456     0.005412  0.061830  0.077600  0.067343  0.086700  0.701116
# GSM5163709     0.014437  0.057581  0.110827  0.062903  0.081840  0.672412
# GSM5163522     0.012732  0.055453  0.110972  0.060470  0.082145  0.678228
#
#                Eosino   Sample_Group
# GSM5163593          0       Covid-19
# GSM5163624          0       Covid-19
# HB_Control_26       0  Helathy Blood
# GSM5163732          0       Covid-19
# HB_Control_49       0  Helathy Blood
# ...               ...            ...
# GSM5163596          0       Covid-19
# GSM5163503          0       Covid-19
# GSM5163456          0       Covid-19
# GSM5163709          0       Covid-19
# GSM5163522          0       Covid-19
#
# [490 rows x 8 columns]

# %%
spain_cfc.Sample_Group = spain_cfc.Sample_Group.map(
    {"Covid-19": "COVID-19 SPAIN", "Helathy Blood": "Healthy"}
)

fig = px.box(
    spain_cfc, color="Sample_Group", labels={"variable": "", "value": "Frequency [%]"}
)


fig.update_layout(legend=dict(font=dict(size=24), title=""), font=dict(size=22))
fig.update_traces(marker=dict(size=10))
fig.update_yaxes(range=[0, 1])

fig.write_image("../Plots/CF_after_CFC.jpg")
fig.show()

# %%
# LR model te estimate methylation level variance explained by WBC composition

# %%
import random

random.seed = 44

# %%
# Load data before and after correction

mynorm_cfc = pd.read_csv(
    "../data/processed/CorrectedMyNorms/mynorm_Spain.csv", index_col=0
)
mynorm_no_cfc = pd.read_csv("../data/interim/Spain/myNorm.csv", index_col=0)

# %%
spain_cf  # Spain cell fraction not corrected
# Out:
#                       B        NK      CD4T      CD8T      Mono    Neutro  \
# GSM5163593     0.002257  0.023829  0.195079  0.049923  0.065042  0.663872
# GSM5163624     0.000000  0.141800  0.125534  0.022799  0.052468  0.657399
# HB_Control_26  0.000000  0.152049  0.158047  0.002009  0.096114  0.591781
# GSM5163732     0.025770  0.091979  0.228205  0.044410  0.106320  0.503316
# HB_Control_49  0.009619  0.068933  0.074765  0.000000  0.092905  0.753778
# ...                 ...       ...       ...       ...       ...       ...
# GSM5163596     0.019290  0.000000  0.200085  0.000000  0.083151  0.697474
# GSM5163503     0.000000  0.000000  0.234437  0.006541  0.100711  0.658311
# GSM5163456     0.000000  0.171187  0.000000  0.129440  0.083872  0.615501
# GSM5163709     0.009710  0.025270  0.107237  0.057689  0.046407  0.753687
# GSM5163522     0.014003  0.000000  0.154039  0.063478  0.057297  0.711183
#
#                Eosino    Sample_Group
# GSM5163593        0.0  COVID-19 SPAIN
# GSM5163624        0.0  COVID-19 SPAIN
# HB_Control_26     0.0         Healthy
# GSM5163732        0.0  COVID-19 SPAIN
# HB_Control_49     0.0         Healthy
# ...               ...             ...
# GSM5163596        0.0  COVID-19 SPAIN
# GSM5163503        0.0  COVID-19 SPAIN
# GSM5163456        0.0  COVID-19 SPAIN
# GSM5163709        0.0  COVID-19 SPAIN
# GSM5163522        0.0  COVID-19 SPAIN
#
# [490 rows x 8 columns]

# %%
def calculate_adj_r2(r2, n, p) -> float:
    """
    Return adj. R2 coefficient.
    """
    param = 1 - (1 - r2) * ((n - 1) / (n - p - 1))

    if param < 0:
        return 0
    else:
        return param


def model(X, y) -> float:
    """
    Calculate adj. R2.
    """
    model = LinearRegression()
    model.fit(X, y)
    r2 = r2_score(y, model.predict(X))
    adj_r2 = calculate_adj_r2(r2=r2, n=len(y), p=X.shape[1])

    return adj_r2


# Use 10.000 random CpGs
# Per each CpG fit model: CpG methylation level ~ WBC fractions

results = []
for cpg in tqdm(random.sample(set(mynorm_cfc.index), 10000)):

    cf = spain_cf.drop(
        "Sample_Group", axis=1
    )  # Estimated WBC fractions by EpiDish package [using raw methylation profiles]

    # Get corrected beta values for specific CpG
    met_level_corrected = mynorm_cfc.loc[cpg, :]

    # Merge corrected beta values with WBC composition
    df_cfc = pd.concat((cf, met_level_corrected), axis=1).astype(float)

    X_cfc = df_cfc.drop(cpg, axis=1).values  # WBC fractions - regressors
    y_cfc = df_cfc[cpg].values.reshape(-1, 1)  # Methylation levels - response variable

    # Fit model
    r2_cfc = model(X_cfc, y_cfc)

    # Get raw beta values
    met_level_no_cfc = mynorm_no_cfc.loc[cpg, :]
    df_no_cfc = pd.concat((cf, met_level_no_cfc), axis=1)

    X_no_cfc = df_no_cfc.drop(cpg, axis=1).values
    y_no_cfc = df_no_cfc[cpg].values.reshape(-1, 1)

    # Fit model using raw beta values before cf-corrction
    r2_no_cfc = model(X_no_cfc, y_no_cfc)

    results.append({"Marker": cpg, "No CFC R2": r2_no_cfc, "CFC R2": r2_cfc})
# Out:
# 100%|██████████| 10000/10000 [00:33<00:00, 294.83it/s]

# %%
results = pd.DataFrame(results).set_index("Marker")
results
# Out:
#             No CFC R2  CFC R2
# Marker
# cg22663813   0.226928     0.0
# cg20164557   0.903860     0.0
# cg18229422   0.090331     0.0
# cg11216264   0.155264     0.0
# cg26457450   0.051335     0.0
# ...               ...     ...
# cg05090186   0.656561     0.0
# cg06657518   0.128959     0.0
# cg19357195   0.078568     0.0
# cg07705135   0.037204     0.0
# cg23677311   0.116975     0.0
#
# [10000 rows x 2 columns]

# %%
# Visualise results
fig = px.box(results, labels={"variable": "", "value": "Adjusted R2"}, points="all")


fig.update_layout(legend=dict(font=dict(size=24), title=""), font=dict(size=22))
fig.update_traces(marker=dict(size=10))


fig.update_yaxes(range=[0, 1])
fig.write_image("../Plots/AdjR2.jpg")
fig.show()
