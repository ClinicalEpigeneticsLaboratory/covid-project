# %%
# Notebook: COVID-19 specific genes methylation
# Description: Notebook contains analysis of the genes methylation chagnes specific for covid-19

# %%
# %load_ext lab_black

# %%
import pandas as pd
from src.utils import EPIC

# %%
# Load EPIC manifest

# %%
epic = pd.read_csv(
    "../data/Additional/EPIC/MethylationEPIC_v-1-0_B4.csv",
    index_col=0,
    low_memory=False,
)

# %%
# Differential methylated promotors of genes -> study all covid groups vs healthy controls

# %%
dmg_in_cov = pd.read_csv("../Files/DMGenesInAllCoVGroupsCorrected.csv", index_col=0)
dmg_in_cov
# Out:
#            UCSC_RefGene_Name UCSC_RefGene_Group
# IlmnID
# cg21465162            UBQLN1             TSS200
# cg24315703             LIMK2             TSS200
# cg25060243            UGT1A4            TSS1500
# cg21581312         LOC723972             TSS200
# cg08585897           TERF2IP            TSS1500
# cg12981595          KRTAP4-8             TSS200
# cg19556901        SNORD115-1            TSS1500
# cg22930808             DTX3L            TSS1500
# cg13407664              HTN1            TSS1500
# cg18642567           RPGRIP1            TSS1500
# cg03782202            HOXD11            TSS1500
# cg17515347              AIM2            TSS1500
# cg21673175         LOC401010             TSS200

# %%
# Differential methylated promotors of genes -> study non-covid-19 vs covid-19

# %%
# Load report
cov_vs_non_cov = pd.read_csv("output/USANoNCoV_vs_CoV_TSS.csv", index_col=0)

# Extract DMPs
cov_vs_non_cov = cov_vs_non_cov[
    (cov_vs_non_cov["Delta mean"].abs() > 0.1) & (cov_vs_non_cov["q-value"] <= 0.05)
].index
print("DMPs [TSS200 | TSS1500]: ", len(cov_vs_non_cov))

# Annotate CpGs to genes
cov_vs_non_cov = epic.loc[cov_vs_non_cov, ["UCSC_RefGene_Name", "UCSC_RefGene_Group"]]
display(cov_vs_non_cov)

# Export
cov_vs_non_cov.to_csv("../Files/DMGenesCoVvsNoNCoV.csv")
# Out:
# DMPs [TSS200 | TSS1500]:  26
#                                     UCSC_RefGene_Name  \
# CpG
# cg15528722                                      TTC33
# cg24678928                                      DDX60
# cg03607951                                     IFI44L
# cg07815522  PARP9;PARP9;PARP9;PARP9;PARP9;PARP9;DTX3L
# cg24103563                 TRIM34;TRIM34;TRIM6-TRIM34
# cg13304609                                     IFI44L
# cg15452182             LOC101928650;GORAB;GORAB;GORAB
# cg17515347                                       AIM2
# cg07863524                                      OR3A4
# cg01036958             LOC101928650;GORAB;GORAB;GORAB
# cg09074025                        LPP-AS1;LPP;LPP;LPP
# cg14333162                                      RSAD2
# cg09584492                          ARHGAP33;ARHGAP33
# cg18205786                        LPP-AS1;LPP;LPP;LPP
# cg12461141                                     TRIM22
# cg16785077                                        MX1
# cg06039489                   C20orf26;C20orf26;CRNKL1
# cg08122652  PARP9;PARP9;DTX3L;PARP9;PARP9;PARP9;PARP9
# cg00959259  PARP9;PARP9;DTX3L;PARP9;PARP9;PARP9;PARP9
# cg24145401                                       AIM2
# cg25656283                                ERCC6;PGBD3
# cg18519762                                       AQP8
# cg18377866                  LOC101929337;LOC100505920
# cg05197514                                TRA2B;TRA2B
# cg22862003                                    MX1;MX1
# cg26312951                                    MX1;MX1
#
#                                      UCSC_RefGene_Group
# CpG
# cg15528722                                      TSS1500
# cg24678928                                      TSS1500
# cg03607951                                      TSS1500
# cg07815522  5'UTR;5'UTR;5'UTR;5'UTR;5'UTR;5'UTR;TSS1500
# cg24103563                           TSS1500;5'UTR;Body
# cg13304609                                      TSS1500
# cg15452182                       TSS1500;Body;Body;Body
# cg17515347                                      TSS1500
# cg07863524                                       TSS200
# cg01036958                       TSS1500;Body;Body;Body
# cg09074025                       TSS1500;Body;Body;Body
# cg14333162                                      TSS1500
# cg09584492                              TSS1500;TSS1500
# cg18205786                       TSS1500;Body;Body;Body
# cg12461141                                      TSS1500
# cg16785077                                      TSS1500
# cg06039489                         TSS200;5'UTR;TSS1500
# cg08122652  5'UTR;5'UTR;TSS1500;5'UTR;5'UTR;5'UTR;5'UTR
# cg00959259  5'UTR;5'UTR;TSS1500;5'UTR;5'UTR;5'UTR;5'UTR
# cg24145401                                      TSS1500
# cg25656283                                 Body;TSS1500
# cg18519762                                      TSS1500
# cg18377866                                  TSS200;Body
# cg05197514                              TSS1500;TSS1500
# cg22862003                                TSS1500;5'UTR
# cg26312951                                 TSS200;5'UTR

# %%
from venn import venn

# %%
# Reload DM genes specific for Covid-19 patients and non-covid-19 patients

# %%
cov_non_cov = (
    pd.read_csv("../Files/DMGenesCoVvsNoNCoVCorrected.csv", index_col=0)
    .UCSC_RefGene_Name.str.split(";")
    .explode()
)  # DM genes between covid and non-covid samples

cov_non_hb = (
    pd.read_csv("../Files/DMGenesInAllCoVGroupsCorrected.csv", index_col=0)
    .UCSC_RefGene_Name.str.split(";")
    .explode()
)  # DM genes between covid and healthy controls

# %%
# Intersection

# %%
common = pd.DataFrame(
    set.intersection(set(cov_non_cov), set(cov_non_hb)), columns=["Gene"]
)
common
# Out:
#     Gene
# 0   AIM2
# 1  DTX3L
