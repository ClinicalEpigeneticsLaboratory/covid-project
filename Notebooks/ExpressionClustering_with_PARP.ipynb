# %%
# Notebook: Clustering  Analysis based on expression data [including PARP9 gene]
# Description: Notebook contains clusterig analysis of genes expresion for covid-19 and non-covid-19 patients
# Data collected from: GSE157103

# %%
# %load_ext lab_black
# Out:
# The lab_black extension is already loaded. To reload it, use:
#   %reload_ext lab_black

# %%
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from sklearn.preprocessing import StandardScaler
import plotly.graph_objects as go
import plotly.express as px
import numpy as np

from IPython.display import display
from src.utils import EPIC
import scipy.stats as sts

# %%
deg = ["TRIM22", "MX1", "TTC33", "DDX60", "AIM2", "DTX3L"]
deg.append("PARP9")

# %%
# Load expression table

# %%
raw_ttable = pd.read_table("../Expression/GSE157103_genes.tpm.tsv", index_col=0).T
raw_ttable
# Out:
# #symbol  A1BG  A1CF   A2M  A2ML1  A3GALT2  A4GALT  A4GNT   AAAS  AACS  AADAC  \
# C1       0.49  0.00  0.21   0.04     0.07     0.0   0.03  18.92  4.07    0.0
# C2       0.29  0.00  0.14   0.00     0.00     0.0   0.05  18.68  3.00    0.0
# C3       0.26  0.00  0.03   0.02     0.00     0.0   0.07  13.85  1.83    0.0
# C4       0.45  0.01  0.09   0.07     0.00     0.0   0.00  22.11  4.22    0.0
# C5       0.17  0.00  0.00   0.05     0.07     0.0   0.00   8.45  1.17    0.0
# ...       ...   ...   ...    ...      ...     ...    ...    ...   ...    ...
# NC22     0.30  0.00  0.02   0.02     0.00     0.0   0.00  17.06  1.96    0.0
# NC23     0.70  0.00  0.02   0.01     0.00     0.0   0.00  20.31  1.54    0.0
# NC24     0.75  0.00  0.27   0.00     0.06     0.0   0.00  27.25  3.42    0.0
# NC25     2.80  0.00  0.04   0.00     0.00     0.0   0.00  21.64  1.43    0.0
# NC26     0.22  0.00  0.28   0.00     0.00     0.0   0.00   5.54  0.35    0.0
#
# #symbol  ...  ZWILCH  ZWINT  ZXDA  ZXDB   ZXDC  ZYG11A  ZYG11B     ZYX  ZZEF1  \
# C1       ...    2.84   4.22  0.95  1.63  15.51    0.06    8.17  363.01  19.17
# C2       ...    3.55  12.15  0.60  1.15  15.62    0.14    8.20  399.80  15.72
# C3       ...    1.34   2.79  0.18  0.32  17.67    0.28    3.62  430.35  13.95
# C4       ...    3.71   5.87  1.40  2.21  15.61    0.27    7.88  209.25  14.78
# C5       ...    1.44   4.46  0.28  0.55   9.34    0.07    5.96  272.91   8.69
# ...      ...     ...    ...   ...   ...    ...     ...     ...     ...    ...
# NC22     ...    0.26   1.01  0.13  0.46   5.93    0.24    1.58  447.14   3.04
# NC23     ...    0.64   0.83  0.18  0.73   8.75    0.12    1.57  748.55   4.55
# NC24     ...    1.18   2.14  0.41  1.29  14.93    0.14    5.05  437.62  10.34
# NC25     ...    0.42   0.61  0.19  0.45   4.77    0.33    1.07  369.66   1.83
# NC26     ...    0.32   2.02  0.05  0.10   3.46    0.10    1.25  577.13   2.08
#
# #symbol  ZZZ3
# C1       6.05
# C2       4.12
# C3       1.81
# C4       7.15
# C5       2.70
# ...       ...
# NC22     1.00
# NC23     1.56
# NC24     3.99
# NC25     0.96
# NC26     0.27
#
# [126 rows x 19472 columns]

# %%
ttable = raw_ttable[deg]

genes_set = set(ttable.columns)  # Update genes
print("Updated number of genes: ", len(genes_set))
ttable
# Out:
# Updated number of genes:  7
# #symbol   TRIM22     MX1  TTC33   DDX60    AIM2   DTX3L   PARP9
# C1        878.28  968.53   6.41  115.76  102.60  145.23  402.93
# C2        236.38   53.01   5.82   15.15   36.29   39.90  112.39
# C3        802.34  861.15   3.44  105.36  157.94  122.19  431.47
# C4        224.91  101.72   6.32   13.57   16.85   40.19  100.88
# C5       1086.22   59.63   5.72   43.04  279.70   95.64  398.58
# ...          ...     ...    ...     ...     ...     ...     ...
# NC22       24.43   11.96   1.06    1.07    5.84    7.99   13.07
# NC23      134.13  117.19   1.36    9.00   61.93   23.73   82.05
# NC24       86.22   48.53   3.78    5.33   15.15   24.23   62.55
# NC25       35.02  101.83   0.86    2.72    4.67   14.29   15.18
# NC26       35.71    3.81   1.57    0.39    4.71    3.87   11.99
#
# [126 rows x 7 columns]

# %%
# Load clinical
clinical = pd.read_excel(
    "../data/Additional/13148_2021_1102_MOESM1_ESM.xlsx", skiprows=1, index_col=1
)  # Load clinical
clinical
# Out:
#                    Sample ID  Covid (1=yes)  Diagnosis  ICU (1=yes) Sex  Age  \
# Albany_sampleID
# C1                  COVID_01              1   COVID-19            0   M   39
# C2                  COVID_02              1   COVID-19            0   M   63
# C3                  COVID_03              1   COVID-19            0   M   33
# C4                  COVID_04              1   COVID-19            0   M   49
# C5                  COVID_05              1   COVID-19            0   M   49
# ...                      ...            ...        ...          ...  ..  ...
# NC22             NONCOVID_22              0  pneumonia            0   M   63
# NC23             NONCOVID_23              0  pneumonia            0   F   42
# NC24             NONCOVID_24              0  pneumonia            0   F   32
# NC25             NONCOVID_25              0  pneumonia            0   M   62
# NC26             NONCOVID_26              0  pneumonia            1   M   36
#
#                 Ethnicity    BMI  WHO ordinal at day 28  Charlson  ...  \
# Albany_sampleID                                                    ...
# C1                      W  31.60                      8         0  ...
# C2                      H  28.70                      0         2  ...
# C3                      W  29.41                      3         2  ...
# C4                      W  27.55                      0         1  ...
# C5                      H  30.40                      0         1  ...
# ...                   ...    ...                    ...       ...  ...
# NC22                   AA  25.40                      0         2  ...
# NC23                    W  27.46                      0         2  ...
# NC24                    W  18.50                      0         0  ...
# NC25                    W  17.90                      0         8  ...
# NC26                    W  19.10                      9         3  ...
#
#                  Rheumatic disease  PUD  Liver disese  DM  Hemiplegia  \
# Albany_sampleID
# C1                               0    0             0   0           0
# C2                               0    0             0   0           0
# C3                               0    0             0   1           0
# C4                               0    0             0   0           0
# C5                               0    0             0   0           0
# ...                            ...  ...           ...  ..         ...
# NC22                             0    0             0   0           0
# NC23                             0    0             0   0           0
# NC24                             0    0             0   0           0
# NC25                             0    0             0   0           0
# NC26                             0    0             1   0           0
#
#                  Renal disease  Cancer (solid) HIV/AIDS  Leukemia/lymphoma  \
# Albany_sampleID
# C1                           0               0        0                  0
# C2                           0               0        0                  0
# C3                           0               0        0                  0
# C4                           0               0        0                  0
# C5                           0               0        0                  0
# ...                        ...             ...      ...                ...
# NC22                         0               0        0                  0
# NC23                         1               0        0                  0
# NC24                         0               0        0                  0
# NC25                         0               0        0                  0
# NC26                         0               0        0                  0
#
#                  Smoking 1=y (current or former);0=never;?=unknown
# Albany_sampleID
# C1                                                               0
# C2                                                               1
# C3                                                               0
# C4                                                               0
# C5                                                               0
# ...                                                            ...
# NC22                                                             0
# NC23                                                             0
# NC24                                                             0
# NC25                                                             1
# NC26                                                             1
#
# [129 rows x 54 columns]

# %%
prepared_set = pd.concat((clinical[["Covid (1=yes)", "ICU (1=yes)"]], ttable), axis=1)

# %%
prepared_set = prepared_set.dropna()
prepared_set
# Out:
#       Covid (1=yes)  ICU (1=yes)   TRIM22     MX1  TTC33   DDX60    AIM2  \
# C1                1            0   878.28  968.53   6.41  115.76  102.60
# C2                1            0   236.38   53.01   5.82   15.15   36.29
# C3                1            0   802.34  861.15   3.44  105.36  157.94
# C4                1            0   224.91  101.72   6.32   13.57   16.85
# C5                1            0  1086.22   59.63   5.72   43.04  279.70
# ...             ...          ...      ...     ...    ...     ...     ...
# NC22              0            0    24.43   11.96   1.06    1.07    5.84
# NC23              0            0   134.13  117.19   1.36    9.00   61.93
# NC24              0            0    86.22   48.53   3.78    5.33   15.15
# NC25              0            0    35.02  101.83   0.86    2.72    4.67
# NC26              0            1    35.71    3.81   1.57    0.39    4.71
#
#        DTX3L   PARP9
# C1    145.23  402.93
# C2     39.90  112.39
# C3    122.19  431.47
# C4     40.19  100.88
# C5     95.64  398.58
# ...      ...     ...
# NC22    7.99   13.07
# NC23   23.73   82.05
# NC24   24.23   62.55
# NC25   14.29   15.18
# NC26    3.87   11.99
#
# [126 rows x 9 columns]

# %%
prepared_set = prepared_set.drop("ICU (1=yes)", axis=1)
display(prepared_set)

pal = sns.color_palette("Accent", prepared_set["Covid (1=yes)"].nunique())
lut = dict(zip(prepared_set["Covid (1=yes)"].unique()[::-1], pal))
colors = prepared_set["Covid (1=yes)"].map(lut)
colors.name = ""

plt.figure(figsize=(13, 13))
sns.set(font_scale=2)

prepared_set = prepared_set.drop("Covid (1=yes)", axis=1)
df_ttable = StandardScaler().fit_transform(prepared_set).T
df_ttable = pd.DataFrame(
    df_ttable, index=prepared_set.columns, columns=prepared_set.index
)

fig = sns.clustermap(df_ttable, method="ward", col_colors=colors, cmap="vlag")
fig.savefig("../Plots/ClusterMapsExpression/DEG_clustering_STATUS.jpg")
plt.show()
# Out:
#       Covid (1=yes)   TRIM22     MX1  TTC33   DDX60    AIM2   DTX3L   PARP9
# C1                1   878.28  968.53   6.41  115.76  102.60  145.23  402.93
# C2                1   236.38   53.01   5.82   15.15   36.29   39.90  112.39
# C3                1   802.34  861.15   3.44  105.36  157.94  122.19  431.47
# C4                1   224.91  101.72   6.32   13.57   16.85   40.19  100.88
# C5                1  1086.22   59.63   5.72   43.04  279.70   95.64  398.58
# ...             ...      ...     ...    ...     ...     ...     ...     ...
# NC22              0    24.43   11.96   1.06    1.07    5.84    7.99   13.07
# NC23              0   134.13  117.19   1.36    9.00   61.93   23.73   82.05
# NC24              0    86.22   48.53   3.78    5.33   15.15   24.23   62.55
# NC25              0    35.02  101.83   0.86    2.72    4.67   14.29   15.18
# NC26              0    35.71    3.81   1.57    0.39    4.71    3.87   11.99
#
# [126 rows x 8 columns]

# %%
df_ttable
# Out:
#               C1        C2        C3        C4        C5        C6        C7  \
# TRIM22  2.105047 -0.346627  1.815002 -0.390435  2.899254 -0.683192 -0.326766
# MX1     4.305061 -0.415208  3.751428 -0.164068 -0.381077 -0.472283 -0.299872
# TTC33   0.828730  0.555088 -0.548757  0.786988  0.508708 -0.084956  1.649656
# DDX60   3.265653 -0.241447  2.903126 -0.296523  0.730753 -0.421664 -0.098179
# AIM2    1.017514 -0.351898  2.160378 -0.753366  4.674925 -0.793844 -0.682531
# DTX3L   3.361594 -0.079247  2.608941 -0.069773  1.741626 -0.352345  0.053056
# PARP9   2.264765 -0.308322  2.517522 -0.410258  2.226241 -0.589330 -0.438420
#
#               C8        C9       C10  ...      NC17      NC18      NC19  \
# TRIM22 -0.208326  0.261155  0.120677  ... -0.057422 -0.956662 -0.973009
# MX1    -0.529668 -0.377261 -0.198096  ... -0.194229 -0.632424 -0.596848
# TTC33   0.995698  0.541174 -0.330770  ...  0.499432 -0.966177 -0.952263
# DDX60  -0.615477 -0.330336 -0.140357  ... -0.147678 -0.715172 -0.727721
# AIM2    0.021071  0.228827 -0.186271  ... -0.065253 -0.772159 -0.832256
# DTX3L  -0.324251  0.059589 -0.290604  ... -0.112240 -0.877634 -1.003403
# PARP9  -0.285650  0.092510 -0.311334  ... -0.210018 -0.834205 -0.926930
#
#             NC20      NC21      NC22      NC23      NC24      NC25      NC26
# TRIM22  0.203902 -1.115587 -1.156149 -0.737161 -0.920148 -1.115702 -1.113066
# MX1    -0.531472 -0.536061 -0.626855 -0.084307 -0.438307 -0.163501 -0.668875
# TTC33   0.082012 -1.253733 -1.652601 -1.513461 -0.391064 -1.745361 -1.416063
# DDX60  -0.592819 -0.697743 -0.732252 -0.455826 -0.583756 -0.674736 -0.755956
# AIM2    0.526624 -0.902471 -0.980741  0.177611 -0.788474 -1.004904 -1.004078
# DTX3L  -0.609109 -0.907361 -1.121658 -0.607476 -0.591142 -0.915855 -1.256247
# PARP9  -0.339851 -1.070135 -1.187923 -0.577020 -0.749717 -1.169236 -1.197487
#
# [7 rows x 126 columns]

# %%
# Only COVID-19 patients
df_ttable = df_ttable.T
df_ttable = df_ttable.loc[[name for name in df_ttable.index if name.startswith("C")]]

# %%
fig = plt.figure(figsize=(26, 10))

Z = linkage(df_ttable, "ward")
dn = dendrogram(
    Z,
    labels=df_ttable.index,
    color_threshold=12,
    above_threshold_color="00000",
    truncate_mode=None,
)

plt.show()

# %%
cls_ = fcluster(Z, t=12, criterion="distance")
cls_ = pd.DataFrame(cls_, index=df_ttable.index, columns=["Cluster"])
cls_ = pd.concat((cls_, clinical[["ICU (1=yes)", "Covid (1=yes)"]]), axis=1).dropna()
cls_
# Out:
#       Cluster  ICU (1=yes)  Covid (1=yes)
# C1        1.0            0              1
# C2        3.0            0              1
# C3        1.0            0              1
# C4        3.0            0              1
# C5        1.0            0              1
# ...       ...          ...            ...
# C99       2.0            1              1
# C100      3.0            0              1
# C101      2.0            1              1
# C102      1.0            0              1
# C103      1.0            0              1
#
# [100 rows x 3 columns]

# %%
cross_table = pd.crosstab(cls_["Cluster"], cls_["ICU (1=yes)"], margins=True)
cross_table
# Out:
# ICU (1=yes)   0   1  All
# Cluster
# 1.0          13   2   15
# 2.0           5  15   20
# 3.0          32  33   65
# All          50  50  100

# %%
_, pval, _, _ = sts.chi2_contingency(pd.crosstab(cls_["Cluster"], cls_["ICU (1=yes)"]))
pval
# Out:
# 0.0014430077318524671

# %%
cross_table.to_csv("../Plots/ClusterMapsExpression/crsTable_ICU.csv")

# %%
cross_table = pd.crosstab(cls_["Cluster"], cls_["Covid (1=yes)"], margins=True)
cross_table
# Out:
# Covid (1=yes)    1  All
# Cluster
# 1.0             15   15
# 2.0             20   20
# 3.0             65   65
# All            100  100

# %%
_, pval, _, _ = sts.chi2_contingency(
    pd.crosstab(cls_["Cluster"], cls_["Covid (1=yes)"])
)
pval
# Out:
# 1.0
